# %%
import pandas as pd

# %%
df = pd.read_csv("menu.csv")
df.info()
df
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_6668\1287996498.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("menu.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1179936 entries, 0 to 1179935
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1179936 non-null  int64
#  1   menu_id     1179936 non-null  object
#  2   r_id        1179936 non-null  int64
#  3   f_id        1179936 non-null  object
#  4   cuisine     1179936 non-null  object
#  5   price       1179936 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 54.0+ MB
#          Unnamed: 0    menu_id    r_id       f_id             cuisine price
# 0                 0        mn0  567335        fd0    Beverages,Pizzas  40.0
# 1                 1        mn0  567335   fd669322    Beverages,Pizzas  40.0
# ...

# %%
file_path = "menu.csv"  # Update this path to the location of your file
output_file_path = "cleaned_menu.csv"

# Read the CSV file
menu_data = pd.read_csv(file_path)

# Step 1: Extract numeric values from the 'price' column
menu_data["price_cleaned"] = (
    menu_data["price"].astype(str).str.extract(r"(\d+\.?\d*)")[0]
)

# Step 2: Convert 'price_cleaned' to float
menu_data["price_cleaned"] = menu_data["price_cleaned"].astype(float)

# Step 3: Handle missing or problematic values (if needed)
# Replace NaN values with 0 or another default value (optional)
menu_data["price_cleaned"].fillna(0, inplace=True)

# Step 4: Save the cleaned data to a new CSV file
menu_data.to_csv(output_file_path, index=False)

print(f"Cleaned data has been saved to {output_file_path}")
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_6668\590274294.py:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   menu_data = pd.read_csv(file_path)
# C:\Users\shlok\AppData\Local\Temp\ipykernel_6668\590274294.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   menu_data["price_cleaned"].fillna(0, inplace=True)
# Cleaned data has been saved to cleaned_menu.csv

# %%
users_df = pd.read_csv("users.csv")


# Define mapping function
def categorize_income(income):
    if income == "No Income":
        return "No Income"
    elif "Below Rs.10000" in income:
        return "Below 10K"
    elif "10001 to 25000" in income:
        return "10K to 25K"
    elif "25001 to 50000" in income:
        return "25K to 50K"
    elif "More than 50000" in income:
        return "More than 50K"
    else:
        return "Unknown"


# Apply categorization
users_df["Income Bracket"] = users_df["Monthly Income"].apply(categorize_income)

# Display results
print(users_df.head())
# Out:
#    Unnamed: 0  user_id               name                          email  \
# 0           0        1    Claire Ferguson        fordanthony@example.net
# 1           1        2     Jennifer Young              ann96@example.com
# 2           2        3  Jermaine Roberson            uwalker@example.org
# 3           3        4   Rachel Carpenter  kimberlypatterson@example.net
# 4           4        5       Shawn Parker    daniellebennett@example.com
#
#      password  Age  Gender Marital Status Occupation  Monthly Income  \
# 0  NKz0fWDh!5   20  Female         Single    Student       No Income
# 1  +i5Q91jt!s   24  Female         Single    Student  Below Rs.10000
# 2  eO4GqGusF(   22    Male         Single    Student  Below Rs.10000
# 3  d^c7O6odaS   22  Female         Single    Student       No Income
# 4  8J#E5RMl1o   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size Income Bracket
# ...

# %%
menu_df = pd.read_csv("cleaned_menu1.csv")
food_df = pd.read_csv("food.csv")
orders_df = pd.read_csv("orders.csv")
resturant_df = pd.read_csv("restaurant.csv")
users_df = pd.read_csv("users.csv")
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_6668\2667313841.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   menu_df = pd.read_csv("cleaned_menu1.csv")

# %%
menu_df.info()
print("--------------------")
food_df.info()
print("--------------------")
orders_df.info()
print("--------------------")
resturant_df.info()
print("--------------------")
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1179936 entries, 0 to 1179935
# Data columns (total 7 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Unnamed: 0     1179936 non-null  int64
#  1   menu_id        1179936 non-null  object
#  2   r_id           1179936 non-null  int64
#  3   f_id           1179936 non-null  object
#  4   cuisine        1179936 non-null  object
#  5   price          1179936 non-null  object
#  6   price_cleaned  1179936 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 63.0+ MB
# --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371561 entries, 0 to 371560
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      371561 non-null  int64
#  1   f_id            371561 non-null  object
#  2   item            371560 non-null  object
# ...

# %%
for df in [menu_df, food_df, orders_df, resturant_df, users_df]:
    df.replace("", pd.NA, inplace=True)
    df.dropna(inplace=True)

# Save cleaned data to separate CSV files
menu_df.to_csv("cleaned_menu.csv", index=False)
food_df.to_csv("cleaned_food.csv", index=False)
orders_df.to_csv("cleaned_orders.csv", index=False)
resturant_df.to_csv("cleaned_restaurant.csv", index=False)
users_df.to_csv("cleaned_users.csv", index=False)

print("Cleaned data saved as CSV files")
# Out:
# Cleaned data saved as CSV files
